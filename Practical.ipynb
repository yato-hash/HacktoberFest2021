# %% [markdown]
# <a href="https://colab.research.google.com/github/yato-hash/HacktoberFest2021/blob/master/Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Experiment 11 - Research Workflow")

for i in range(3):
    print("Iteration", i+1)
# Out:
# Experiment 11 - Research Workflow
# Iteration 1
# Iteration 2
# Iteration 3

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x,y, marker='o')
plt.title("Sample Graph")
plt.show()
